# %% [markdown]
# # COMP 205: Final Examination
#
# ## Fall 2019
#
# Please enter your answers into this workbook in the places provided. You will need to create extra cells in the workbook to explain your reasoning in support of your answers. Please make sure that your "final answer" for each question is in the place marked for that purpose.
#
# This is an open-Internet examination. You may use any books and materials, and the entire Internet -- as well as all of the class workbooks and examples -- in answering these questions. You may not use direct communication with other *people* in completing this workbook.
#
# There are 6 questions. Q1-Q5 are worth 10 points each, Q6 is worth 50 points. These questions vary greatly in difficulty. Point value does not indicate difficulty.
#
# Please note that in general, your code should work for all data having the same overall form as in the examples.

# %% [markdown]
# ### 1. Numpy Problem 1
#
# The next cell downloads the iris dataset into your notebook, just run it.

# %%
import numpy as np
from sklearn import datasets
iris = datasets.load_iris()
iris_data = iris['data']
iris_data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.6, 1.4, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %% [markdown]
# Write an expression for `condition` so as to filter the rows of iris_2d that has petallength (3rd column) >= 1.5 and sepallength (1st column) < 5.0

# %%
#original:
condition = ...
iris_data[condition]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.6, 1.4, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
#answer:

#so based on my limited english skill and my understanding for the materials in this course, this question is asking me to get rid of certian
#numbers within the data set that do not meet our stand and print out the new data set (I guess the "iris_2d" is a typo?)
#I am not sure whether I should get rid of numbers >= 1.5 or keep numbers >=1.5 with "filter the rows of iris_2d that has  (3rd column) >= 1.5"
#and also "sepallength (1st column) < 5.0"

condition = (iris_data[:, 2] >= 1.5) & (iris_data[:, 0] < 5.0)
iris_data[condition]
# Out:
# array([[4.6, 3.1, 1.5, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3.4, 1.9, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [4.9, 2.4, 3.3, 1. ],
#        [4.9, 2.5, 4.5, 1.7]])

# %% [markdown]
# ### 2. Numpy Problem 2
#
# The code in the following cell loads, cleans, normalizes and shows Happiness data as a Pandas DataFrame. No need to change it, just run it!

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
data1 = pd.read_csv('happiness-report.csv').dropna().drop(['Country', 'Year'], axis=1)
scaler = StandardScaler()
pd.DataFrame(scaler.fit_transform(data1.to_numpy()), dtype='float32', columns=list(data1))
# Out:
#      HappinessScore  LifeLadder    LogGDP  SocialSupport  \
# 0         -2.022806   -2.568734 -1.502532      -2.607243
# 1         -0.673497   -0.494147  0.117347      -1.105947
# 2          0.543196    0.213871  0.453157       0.738488
# 3         -0.815904   -0.442019 -0.130115       0.009798
# 4          1.559628    1.456950  1.222674       1.081469
# 5          1.575649    1.653631  1.240304       0.838729
# 6         -0.238264   -0.347233  0.341698      -0.273442
# 7         -0.907579   -0.947830 -0.889183      -0.918669
# 8         -0.135909   -0.288164  0.426776       0.778201
# 9          1.288164    1.201166  1.181645       0.993461
# 10        -0.527529    0.238145 -1.359517      -2.641109
# 11         0.269952    0.324275 -0.348788       0.118173
# 12        -0.079836    0.298830  0.109177       0.192609
# 13        -1.769143   -1.879873  0.343567      -0.156578
# 14         0.733665    0.571407  0.240272       0.581548
# 15        -0.413603   -0.409361  0.506578       0.942625
# 16        -0.790983   -0.563447 -1.522861      -1.265665
# 17        -0.384232   -0.272926 -0.962900      -1.163640
# 18         1.604130    1.455606  1.205973       0.932951
# 19        -1.001924   -0.959407 -1.521126      -2.012630
# 20         0.861832    0.791698  0.669343       0.654702
# 21         0.577907    0.385143  0.201250       0.491723
# 22        -1.337471   -1.420561 -1.700557      -1.637046
# 23        -0.590723   -0.057864 -0.675881      -1.642845
# 24         1.505335    1.424693  0.334445       0.533520
# 25        -0.038894   -0.016502  0.669201       0.822859
# 26         1.224971    1.328683  0.967972       0.987906
# 27         1.890725    1.880643  1.251877       1.235640
# 28        -0.045125   -0.109051  0.298608       0.415121
# 29         0.491573    0.514910  0.000833       0.324389
# ..              ...         ...       ...            ...
# 83         0.138225    0.282460 -0.243062       0.277137
# 84         0.193408    0.327947  0.834973       0.629364
# 85         0.528955    0.535447  0.708343       0.039482
# 86         0.153356   -0.036952  0.725487       0.813644
# 87        -1.906210   -1.790355 -1.440921      -1.680789
# 88        -0.707318   -0.705212 -1.201747      -0.630487
# 89         0.113304    0.342918  0.262968       0.338034
# 90        -0.980562   -1.121633 -1.695468      -1.395447
# 91         0.642881    0.611091  0.911180       0.930052
# 92         0.571677    0.623941  0.949162       1.088579
# 93        -0.670827   -0.602345  0.116777       0.239116
# 94         0.373197    0.256470  1.045768      -0.132808
# 95         0.781728    0.860983  1.006928       0.827189
# 96        -0.987683   -1.036731  0.107202       0.125897
# 97         1.661983    1.634583  1.261454       1.000828
# 98         1.783919    1.754738  1.437996       0.997515
# 99        -1.997885   -1.894549 -1.135681      -1.176386
# 100        0.473772    0.410333  0.389687       0.509475
# 101       -1.237786   -1.375591 -1.677529      -1.849773
# 102       -0.903129   -0.730578  0.026188      -0.685067
# 103       -0.091407   -0.331342  0.739447       0.287574
# 104       -1.145221   -1.107236 -1.532837      -0.626341
# 105       -1.017944   -0.801724 -0.220827       0.747229
# 106        1.404760    1.507647  1.117876       0.982107
# 107        1.260572    1.192646  1.392824       0.772120
# 108        0.727435    0.733769  0.579592       0.886882
# 109        0.621520    0.584464 -0.422413       0.916770
# 110       -0.684177   -0.493015 -0.002693       0.627393
# 111       -1.218205   -1.358894 -0.886470      -0.814951
# 112       -1.613385   -1.740573 -1.452861      -0.323249
#
#      HealthyLifeExpectancyAtBirth  FreedomToMakeLifeChoices  Generosity  \
# 0                       -1.771537                 -3.478933   -0.393732
# 1                        0.591161                  0.353237    0.186115
# 2                        0.605837                  0.537605   -1.177684
# 3                        0.327009                  0.212351   -0.806240
# 4                        1.310244                  1.133960    1.036624
# 5                        1.222193                  1.032635    0.482661
# 6                        0.121557                 -0.086912   -1.465824
# 7                       -0.054544                  1.010177   -0.092612
# 8                        0.209608                 -1.182515   -1.016641
# 9                        1.075442                  0.218669   -0.666017
# 10                      -1.522060                 -0.590172    0.309932
# 11                      -0.157271                  0.685153   -0.410949
# 12                       0.459086                 -1.052893    0.952039
# 13                      -0.847003                  0.297191   -1.512641
# 14                       0.253633                 -0.272622   -0.659904
# 15                       0.312334                 -0.496026   -0.998944
# 16                      -1.580760                 -0.526573    0.123384
# 17                      -1.756862                  0.286000    0.360327
# 18                       1.310244                  1.386969    0.780789
# 19                      -2.417243                 -1.125101    0.224367
# 20                       0.767264                  0.049828   -0.302059
# 21                       0.444410                  0.579025   -0.844390
# 22                      -1.096480                 -1.891848    1.026681
# 23                      -0.993754                 -0.714012   -0.648178
# 24                       0.972716                  1.353853   -0.517753
# 25                       0.811288                 -0.780714   -0.828211
# 26                       0.825965                  0.063451   -1.739226
# 27                       1.134142                  1.299003    0.251683
# 28                       0.165583                  0.714019   -0.818075
# 29                       0.561811                  0.737166   -0.516630
# ..                            ...                       ...         ...
# 83                      -0.406748                  1.149096   -0.575133
# 84                       1.134142                  0.805535   -1.536113
# 85                       0.371034                  0.531355   -1.261799
# 86                      -0.054544                 -0.453967   -0.851958
# 87                      -0.524150                  1.203716    0.518344
# 88                      -0.744277                 -1.304781   -0.244328
# 89                       0.517785                 -0.363752   -0.481240
# 90                      -2.035690                 -0.562788    0.804007
# 91                       0.620512                 -0.212888   -1.002688
# 92                       0.943365                  1.355193   -0.634659
# 93                      -1.199206                 -0.254576   -0.227663
# 94                       1.310244                 -1.551898   -0.452042
# 95                       1.427645                 -0.513757   -0.358164
# 96                       0.371034                  0.594861    0.708825
# 97                       1.163492                  1.352462    0.598414
# 98                       1.383619                  1.222278    0.770530
# 99                      -1.052455                  0.208087    1.062067
# 100                      0.371034                  1.038726    1.767944
# 101                     -1.463359                 -1.451522    0.106159
# 102                      0.327009                 -1.130836   -1.153997
# 103                      0.312334                 -2.160150   -1.015285
# 104                     -1.316607                 -0.460510    0.718325
# 105                     -0.010520                 -1.017106   -0.202023
# 106                      1.119467                  0.466295    1.577481
# 107                      0.532462                  0.356590    0.843399
# 108                      0.635187                  0.795389   -0.545087
# 109                      0.062856                  1.592023    2.153626
# 110                      0.268308                 -1.460969   -0.979969
# 111                     -1.375308                  0.067647    0.386903
# 112                     -1.331283                 -0.170025   -0.095022
#
#      PerceptionsOfCorruption  PositiveAffect  NegativeAffect  \
# 0                   1.024987       -2.615553        1.253094
# 1                   0.871689        0.029998        0.269048
# 2                   0.635500        1.008995        0.286291
# 3                  -0.325043       -1.175901        1.825095
# 4                  -1.790273        0.448267       -1.237708
# 5                  -1.152816        0.387260       -0.795529
# 6                  -0.947465       -1.074464       -1.192630
# 7                  -0.192641       -1.543155        0.752906
# 8                  -0.100939       -2.375790       -0.684764
# 9                  -0.574908        0.361756       -0.517883
# 10                  0.050092       -0.579708        1.974367
# 11                  0.262916        0.292317        1.053375
# 12                  0.945594       -0.613701       -0.207831
# 13                  0.375432        0.179520       -0.325601
# 14                  0.140212        0.363267        0.620243
# 15                  1.156387       -0.649542       -1.218984
# 16                  0.108705        0.007894        0.542457
# 17                  0.792620       -0.618303        0.688813
# 18                 -1.967421        1.039725       -0.413642
# 19                  0.138209       -1.438929        2.844517
# 20                  0.425777        1.121089       -0.225526
# 21                  0.633162        1.056069        0.058595
# 22                  0.304441        0.345095        0.480924
# 23                  0.004384       -1.120837        1.742688
# 24                  0.237383        1.464488        0.347740
# 25                  1.013157       -1.170811       -0.058795
# 26                  0.614650        0.033662       -1.345248
# 27                 -3.157857        1.019177       -1.024691
# 28                  0.134948        0.318841       -0.047030
# 29                  0.503543        1.522830        0.374137
# ..                       ...             ...             ...
# 83                 -0.057723        0.574767        1.122243
# 84                  0.767244       -0.282844        0.257570
# 85                  0.990342        0.231661        0.033736
# 86                  0.689636       -0.335521       -1.107812
# 87                 -3.086783        0.762511        0.145365
# 88                  0.363772        0.035437       -0.554797
# 89                  0.681088       -1.382175        0.009016
# 90                  0.638073       -1.449077        1.955980
# 91                  0.929911        0.403314       -0.484748
# 92                  0.549352       -0.604259       -0.229368
# 93                  0.559796        0.934496       -0.146623
# 94                  0.320955       -0.446564       -0.897625
# 95                  0.211558       -0.465049        0.706550
# 96                  0.650365        1.109477        0.066101
# 97                 -2.553905        1.030640       -1.543559
# 98                 -2.346843        0.752067       -1.191158
# 99                 -0.676533        0.476357       -0.853413
# 100                 0.911884        1.221058       -1.114755
# 101                 0.384004       -0.929246        1.729037
# 102                 0.554003       -1.082229        0.796165
# 103                 0.364305       -2.519228        0.633036
# 104                 0.640081       -0.227363        1.086025
# 105                 1.107648       -0.926296       -0.843722
# 106                -1.792273        0.669234       -0.770136
# 107                -0.146844        0.963919       -0.037600
# 108                -0.292260        1.526905       -0.235545
# 109                -1.167354        1.055761       -0.994823
# 110                 0.486407        0.450121        0.895172
# 111                 0.395812       -0.066996        0.635210
# 112                 0.576032        0.000897       -0.959708
#
#      ConfidenceInNationalGovernment
# 0                         -0.644104
# 1                         -0.289478
# 2                         -1.162530
# 3                          0.892198
# 4                         -0.121382
# 5                         -0.021816
# 6                          1.712856
# 7                          1.699414
# 8                         -0.360027
# 9                         -0.256326
# 10                         0.733592
# 11                        -0.468868
# 12                        -1.198936
# 13                         1.132862
# 14                        -1.630031
# 15                        -1.375072
# 16                         0.648464
# 17                         0.763732
# 18                         0.589311
# 19                         0.423564
# 20                        -0.794253
# 21                        -1.094701
# 22                        -0.881919
# 23                        -0.097111
# 24                        -0.065477
# 25                        -1.228623
# 26                        -0.362512
# 27                         0.699764
# 28                        -0.357556
# 29                        -0.456339
# ..                              ...
# 83                         1.550451
# 84                         0.138517
# 85                        -1.338163
# 86                        -0.186606
# 87                         2.484359
# 88                         0.481230
# 89                        -0.084710
# 90                         1.438646
# 91                        -0.829808
# 92                        -1.273314
# 93                         0.158866
# 94                        -0.521578
# 95                        -1.042885
# 96                         0.417012
# 97                         0.006874
# 98                         1.791174
# 99                         2.115680
# 100                        0.563707
# 101                       -0.852074
# 102                       -0.720257
# 103                        0.103624
# 104                        0.054330
# 105                       -2.074002
# 106                       -0.362128
# 107                       -0.899269
# 108                       -0.658959
# 109                        2.390202
# 110                       -1.165805
# 111                        0.570486
# 112                        0.288439
#
# [113 rows x 11 columns]

# %% [markdown]
# Find the correlation between the Happiness Score and each of the columns of the happiness report.
#
# **Hint:** The function `np.corrcoef` can be used to find the correlation between two columns. For example,
#
# ```
# np.corrcoef(iris_data[:, 0], iris_data[:, 2])[0, 1]
# ```
#
# returns the correlation between SepalLength(1st column) and PetalLength(3rd column) for `iris_data`. The results should be of the form shown below, though the correlation values shown are not real, _they are for illustration only._
#
# ```
# 1 -0.01387966267785501
# 2 0.032361001774926956
# 3 0.3820632143188447
# . . .
# 9 0.5346040379913426
# 10 0.7990333389497359
#
# ```

# %%
#answer:

#I got the list of numbers for this question on step 2 (see below), however as the example demonstrates, I guess
#rather than just print out all the numbers, I am expected to put an index in front of each one and make them easier to read? (I am not sure)
#So in step 3 I turned them into pandas dataframe again

#first transform this sheet above into a 2d array 
df =pd.DataFrame(scaler.fit_transform(data1.to_numpy()), dtype='float32', columns=list(data1))
new_df = df.to_numpy()

#then use: numpy.corrcoef(x, y=None, rowvar=True, bias=<no value>, ddof=<no value>)
array = []
for i in range(1,len(new_df[1])):
    array.append(np.corrcoef(new_df[:, 0], new_df[:, i])[0, 1])

    
#after getting all the numbers, make them into a sheet with index like in the example above:
new_array = np.asarray(array)
dataset = pd.DataFrame(new_array)
dataset
# Out:
#           0
# 0  0.984006
# 1  0.799491
# 2  0.778988
# 3  0.775260
# 4  0.492594
# 5 -0.085630
# 6 -0.475740
# 7  0.451048
# 8 -0.493151
# 9 -0.173102

# %% [markdown]
# ### 3. Pandas Problem 1
#
# Given a pandas DataFrame df
#
# 1. Interchange columns `'b'` and `'d'` to obtain `df2`
# 2. Interchange rows 1 and 2 in `df2` to obtain `df3` ([Hint](https://stackoverflow.com/questions/46890972/swapping-rows-within-the-same-pandas-dataframe)).
# 3. Verify that after `df3` was obtained, `df2`'s value didn't change.

# %%
df = pd.DataFrame(np.arange(20).reshape(4, 5), columns=list('abcde'))
df
# Out:
#     a   b   c   d   e
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19

# %%
#answer 1:

cols = list(df.columns)
a, b = cols.index('b'), cols.index('d')
cols[b], cols[a] = cols[a], cols[b]
df2 = df[cols]
df2
# Out:
#     a   d   c   b   e
# 0   0   3   2   1   4
# 1   5   8   7   6   9
# 2  10  13  12  11  14
# 3  15  18  17  16  19

# %%
#answer 2:

b, c = df2.iloc[1], df2.iloc[2]
temp = df2.iloc[1].copy()
df3 = df2.copy()
df3.iloc[1] = c
df3.iloc[2] = temp
df3
# Out:
#     a   d   c   b   e
# 0   0   3   2   1   4
# 1  10  13  12  11  14
# 2   5   8   7   6   9
# 3  15  18  17  16  19

# %%
#answer 3:
df2
# Out:
#     a   d   c   b   e
# 0   0   3   2   1   4
# 1   5   8   7   6   9
# 2  10  13  12  11  14
# 3  15  18  17  16  19

# %%
# I swaped two coloums in df to make df2
# I swaped two rows in df2 to make df3
# df2 is still the same

# %% [markdown]
# ### 4. Pandas Problem 2
#
# Run the following 4 cells, then answer the questions after

# %%
df4 = pd.DataFrame(np.arange(9).reshape(3, 3), columns=list('abc')) # Line 1
df4['rows'] = list('ijk')                                           # Line 2
df5 = df4.set_index('rows')                                         # Line 3
df6 = df5                                                           # Line 4
df7 = df6[['a', 'b', 'c']]                                          # Line 5
df5.loc['j':'j', 'b':'b'] = 42                                      # Line 6

# %%
df4 # I added this cell
# Out:
#    a  b  c rows
# 0  0  1  2    i
# 1  3  4  5    j
# 2  6  7  8    k

# %%
df5
# Out:
#       a   b  c
# rows
# i     0   1  2
# j     3  42  5
# k     6   7  8

# %%
df6
# Out:
#       a   b  c
# rows
# i     0   1  2
# j     3  42  5
# k     6   7  8

# %%
df7
# Out:
#       a  b  c
# rows
# i     0  1  2
# j     3  4  5
# k     6  7  8

# %% [markdown]
# #### Pandas Problem 2 questions
#
# 1. Even though `df6` is created in line 4, _before_ any elements of `df5` are set to 42, why do we see a 42 in `df6`?
# 2. How do you explain the difference between `df6` and `df7`?
#
# **Your answer:**
#
# 1. because by using "df6 = df5", we made a new pointer that allows df6 to point to the "real" dataframe that df5 is pointing to, so after using df5 to give this dataframe a new value, when we print out df6, it also shows this changed value
#
# 2. the explaination above does not apply to df7, because we gave df7 a new piece of memory and put the original df5/df6 value into it, so it does not change after modifying df5

# %% [markdown]
# ### 5. Matplotlib Problem 1
#
# Randall Munroe, the creator of XKCD cartoons, used Matplotlib to create this graph:
#
# <img align="center" style="padding:10px; height: 50%; width: 50%;" src="figures/bacon-health.png">
#
# The code is shown below

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
with plt.xkcd():
    # Based on "Stove Ownership" from XKCD by Randall Munroe
    # https://xkcd.com/418/
    fig = plt.figure(figsize=(6.1, 6.2))
    ax = fig.add_axes((0.1, 0.2, 0.8, 0.7))
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_ylim([-30, 10])

    data = np.ones(100)
    data[70:] -= np.arange(30)

    ax.annotate(
        'THE DAY I REALIZED\nI COULD COOK BACON\nWHENEVER I WANTED',
        xy=(70, 1), arrowprops=dict(arrowstyle='->'), xytext=(15, -10))

    ax.plot(data)

    ax.set_xlabel('time')
    ax.set_ylabel('my overall health')
    fig.text(
        0.5, 0.05,
        '"Stove Ownership" from xkcd by Randall Munroe',
        ha='center')
# Out:
# /opt/tljh/user/lib/python3.6/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['xkcd', 'xkcd Script', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# Write a modified version of the above code to tell a different story (as depicted below).
#
# <img align="center" style="padding:10px; height: 50%; width: 50%;" src="figures/health-graph.png">

# %%
#answer:
#this question asks me to draw a new turn at the end of the original function

with plt.xkcd():
    
    #this part is same as the original:    
    fig = plt.figure(figsize=(6.1, 6.2))
    ax = fig.add_axes((0.1, 0.2, 0.8, 0.7))
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_ylim([-30, 10])

    data = np.ones(100)
    data[70:] -= np.arange(30)
    
    ax.annotate(
        'THE DAY I REALIZED\nI COULD COOK BACON\nWHENEVER I WANTED',
        xy=(70, 1), arrowprops=dict(arrowstyle='->'), xytext=(15, -10))
 

    #add new change to the graph:
    data[85:] += 1.3*np.arange(15)
    ax.annotate(
        'THE DAY I GOT MY HEART \"EVENT\"',
        xy=(85, data[85]), arrowprops=dict(arrowstyle='->'), xytext=(20, -22))

    
    #still the same as original:
    ax.plot(data)

    ax.set_xlabel('time')
    ax.set_ylabel('my overall health')
    fig.text(
        0.5, 0.05,
        '"Stove Ownership" from xkcd by Randall Munroe',
        ha='center')

# %% [markdown]
# ### 6. Case Study
#
# A group of researchers asked 54 questions each from research subjects about their relationships. Each question was scored on a 5-point scale (recorded as digits 0 &ndash; 4). A final attribute 'Class' was used to record whether the relationship later ended in a divorce. The dataset [is available](https://archive.ics.uci.edu/ml/datasets/Divorce+Predictors+data+set#) in divorce.csv.

# %%
# %more divorce.csv

# %% [markdown]
# Based on the data you are to create a K-neighbors classifier with 7 neighbors.
#
# Six additional subjects answered the same questions; their answers are recorded in the following variables:
# <span style="font-size:75%;">
#
# s1 = [4, 0, 1, 2, 4, 0, 4, 3, 2, 2, 0, 1, 4, 0, 0, 1, 1, 2, 2, 1, 2, 4, 1, 3, 0, 1, 1, 4, 1, 0, 0, 1, 2, 2, 0, 1, 1, 4, 0, 0, 2, 4, 1, 1, 0, 3, 0, 0, 1, 0, 4, 3, 0, 2]
# <br/>
# s2 = [3, 0, 2, 2, 3, 1, 3, 4, 0, 4, 0, 1, 1, 2, 1, 3, 0, 4, 3, 4, 2, 1, 0, 1, 0, 4, 0, 2, 3, 2, 4, 3, 4, 1, 1, 2, 4, 1, 4, 4, 0, 3, 1, 1, 2, 4, 2, 3, 3, 4, 4, 1, 2, 4]
# <br/>
# s3 = [1, 2, 2, 4, 4, 3, 2, 2, 2, 1, 3, 1, 1, 0, 3, 2, 4, 0, 4, 3, 0, 4, 1, 3, 0, 2, 2, 4, 1, 0, 1, 0, 3, 3, 1, 2, 1, 3, 1, 1, 3, 1, 2, 4, 4, 0, 2, 3, 3, 3, 3, 1, 2, 1]
# <br/>
# s4 = [0, 2, 3, 0, 4, 0, 1, 1, 1, 4, 1, 3, 0, 3, 3, 3, 0, 1, 0, 3, 2, 0, 1, 0, 4, 2, 0, 2, 0, 0, 2, 4, 2, 3, 4, 0, 1, 1, 0, 0, 0, 1, 1, 2, 4, 3, 4, 1, 2, 4, 3, 1, 0, 2]
# <br/>
# s5 = [4, 0, 4, 2, 2, 1, 2, 0, 1, 4, 0, 0, 0, 4, 0, 0, 0, 4, 0, 0, 2, 1, 4, 0, 3, 1, 0, 0, 2, 0, 4, 0, 2, 2, 4, 1, 2, 3, 2, 2, 0, 2, 0, 4, 1, 1, 4, 1, 1, 3, 2, 3, 3, 1]
# <br/>
# s6 = [3, 0, 3, 3, 0, 1, 0, 0, 2, 1, 3, 3, 1, 0, 2, 2, 1, 1, 0, 0, 2, 3, 4, 0, 3, 2, 3, 4, 2, 0, 3, 2, 1, 2, 3, 3, 2, 0, 0, 3, 1, 2, 4, 2, 0, 1, 3, 3, 1, 0, 2, 3, 2, 1]
# </span>
#
# Using the classifier, predict how the subjects' relationship is likely to fare.

# %%
#answer

#use KNN to predict the divorce result of s1 to s6

import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
divorce = pd.read_csv('divorce.csv',sep=';')
new_class=divorce['Class']
divorce=divorce.drop(['Class'],axis=1)
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(divorce, new_class)
result=[]
s1 = [4, 0, 1, 2, 4, 0, 4, 3, 2, 2, 0, 1, 4, 0, 0, 1, 1, 2, 2, 1, 2, 4, 1, 3, 0, 1, 1, 4, 1, 0, 0, 1, 2, 2, 0, 1, 1, 4, 0, 0, 2, 4, 1, 1, 0, 3, 0, 0, 1, 0, 4, 3, 0, 2]
result.append(s1)
s2 = [3, 0, 2, 2, 3, 1, 3, 4, 0, 4, 0, 1, 1, 2, 1, 3, 0, 4, 3, 4, 2, 1, 0, 1, 0, 4, 0, 2, 3, 2, 4, 3, 4, 1, 1, 2, 4, 1, 4, 4, 0, 3, 1, 1, 2, 4, 2, 3, 3, 4, 4, 1, 2, 4]
result.append(s2)
s3 = [1, 2, 2, 4, 4, 3, 2, 2, 2, 1, 3, 1, 1, 0, 3, 2, 4, 0, 4, 3, 0, 4, 1, 3, 0, 2, 2, 4, 1, 0, 1, 0, 3, 3, 1, 2, 1, 3, 1, 1, 3, 1, 2, 4, 4, 0, 2, 3, 3, 3, 3, 1, 2, 1]
result.append(s3)
s4 = [0, 2, 3, 0, 4, 0, 1, 1, 1, 4, 1, 3, 0, 3, 3, 3, 0, 1, 0, 3, 2, 0, 1, 0, 4, 2, 0, 2, 0, 0, 2, 4, 2, 3, 4, 0, 1, 1, 0, 0, 0, 1, 1, 2, 4, 3, 4, 1, 2, 4, 3, 1, 0, 2]
result.append(s4)
s5 = [4, 0, 4, 2, 2, 1, 2, 0, 1, 4, 0, 0, 0, 4, 0, 0, 0, 4, 0, 0, 2, 1, 4, 0, 3, 1, 0, 0, 2, 0, 4, 0, 2, 2, 4, 1, 2, 3, 2, 2, 0, 2, 0, 4, 1, 1, 4, 1, 1, 3, 2, 3, 3, 1]
result.append(s5)
s6 = [3, 0, 3, 3, 0, 1, 0, 0, 2, 1, 3, 3, 1, 0, 2, 2, 1, 1, 0, 0, 2, 3, 4, 0, 3, 2, 3, 4, 2, 0, 3, 2, 1, 2, 3, 3, 2, 0, 0, 3, 1, 2, 4, 2, 0, 1, 3, 3, 1, 0, 2, 3, 2, 1]
result.append(s6)
prediction = knn.predict(result)
print(prediction)
# Out:
# [0 1 1 0 0 1]

# %% [markdown]
# # When you are done with this notebook,
# * Save and checkpoint.
# * Ensure that the name of this file is precisely `final-2019.ipynb`.
# * Save and checkpoint the notebook.

# %% [markdown]
# * If your Jupyter installation can download the notebook as a PDF,
#     * (File >> Download as >> PDF via LaTeX (.pdf)),
#     * Rename the downloaded file to `<loginid>-final-2019.pdf`. In other words, my filename would be `jsingh11-final-2019.pdf`.
#     * Submit the file `<loginid>-final-2019.pdf` to Canvas.
# * Otherwise
#     * (File >> Download as >> Notebook (.ipynb)). In other words, my filename would be `jsingh11-final-2019.ipynb`.
#     * Rename the downloaded file to `<loginid>-final-2019.ipynb`,
#     * Submit the file `<loginid>-final-2019.ipynb` to Canvas.
